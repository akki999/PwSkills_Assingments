# %% [markdown]
# ## Python Matplotlib Assignment:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# A. Matplotlib:
#
#     It is the python liabrary that we can used to plot data for visualization.
#
#     We can use matplolib to visualize trillions of data by simply plotting them.
#
# B. Five plots of matplotlib:
#
#     line plot.
#     scatter plot.
#     bar plot.
#     histogram.
#     3d-plot

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %%
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %% [markdown]
# A scatter plot (aka scatter chart, scatter graph) uses dots to represent values for two different numeric variables.
#
# The position of each dot on the horizontal and vertical axis indicates values for an individual data point.
#
# Scatter plots are used to observe relationships between variables.

# %%
plt.figure(figsize=(6,2))
plt.scatter(x,y, alpha=0.9, c='#E7A437', marker='x')
plt.xlabel("Values of Array X on X-axis.")
plt.ylabel("Values of Array Y on Y-axis.")
plt.title("Example of Scatter Plot X-axis vs Y-axis.")
plt.grid()
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

# %% [markdown]
# Subplots mean groups of axes that can exist in a single matplotlib figure.
#
# subplots() function in the matplotlib library, helps in creating multiple layouts of subplots.
#
# It provides control over all the individual plots that are created.

# %%
plt.figure(figsize=(15,5))
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(2, 2, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(2, 2, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(2, 2, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2, 2, 4)
plt.plot(x,y)

plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [markdown]
# A bar plot or bar chart is a graph that represents the category of data with rectangular bars with lengths and heights that is proportional to the values which they represent.
#
# The bar plots can be plotted horizontally or vertically.
#
# A bar chart describes the comparisons between the discrete categories.
#
# One of the axis of the plot represents the specific categories being compared, while the other axis represents the measured values corresponding to those categories.

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.figure(figsize=(6,2))
plt.bar(company,profit, color='#37E77A')
plt.xlabel("Company Names on X-axis.")
plt.ylabel("Profit of comapnies on Y-axis.")
plt.title("Vertical Bar chart Comapny Names vs Companie's profit.")
plt.show()

# %%
plt.figure(figsize=(6,2))
plt.barh(company,profit, color='#C437E7')
plt.xlabel("Profit of comapnies on X-axis.")
plt.ylabel("Company Names on Y-axis.")
plt.title("Horizontal Bar chart Companie's profit vs Comapny Names.")
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %% [markdown]
# A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum.
#
# In the box plot, a box is created from the first quartile to the third quartile, a vertical line is also there which goes through the box at the median.
#
# Here x-axis denotes the data to be plotted while the y-axis shows the frequency distribution.

# %%
box1 = np.random.normal(100, 10, 200)

# %%
plt.figure(figsize=(6,2))
plt.boxplot(box1)
plt.show()

# %%
box2 = np.random.normal(90, 20, 200)

# %%
plt.figure(figsize=(6,2))
plt.boxplot(box2)
plt.show()
